# %%
 dbutils.fs.mount(
    source = "wasbs://files@stgdemodata.blob.core.windows.net",
    mount_point = "/mnt/curso",
    extra_configs = {"fs.azure.account.key.stgdemodata.blob.core.windows.net":"6pdnHmKLx6kfcWZr5U70GQwnxgaq/57QG8JI7eo8T9lwMKSvdNYrUOuNj00g1NqnNVONV6BQPa4oadQ9ygB/PA=="})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">13</span><span class="ansired">]: </span>True
# </div>

# %%
# %fs mounts
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mountPoint</th><th>source</th><th>encryptionType</th></tr></thead><tbody><tr><td>/mnt/curso</td><td>wasbs://files@stgdemodata.blob.core.windows.net</td><td></td></tr><tr><td>/</td><td>DatabricksRoot</td><td>sse-s3</td></tr><tr><td>/databricks-datasets</td><td>databricks-datasets</td><td>sse-s3</td></tr><tr><td>/databricks-results</td><td>databricks-results</td><td>sse-s3</td></tr></tbody></table></div>

# %%
dbutils.fs.ls("/mnt/curso")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">14</span><span class="ansired">]: </span>
# [FileInfo(path=&apos;dbfs:/mnt/curso/Airlines/&apos;, name=&apos;Airlines/&apos;, size=0),
#  FileInfo(path=&apos;dbfs:/mnt/curso/JSON/&apos;, name=&apos;JSON/&apos;, size=0),
#  FileInfo(path=&apos;dbfs:/mnt/curso/NBA/&apos;, name=&apos;NBA/&apos;, size=0),
#  FileInfo(path=&apos;dbfs:/mnt/curso/OnlineRetail/&apos;, name=&apos;OnlineRetail/&apos;, size=0)]
# </div>

# %%
# %fs unmount /mnt/curso
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/mnt/curso has been unmounted.
# res1: Boolean = true
# </div>

# %%
dbutils.fs.mkdirs("/foobar/")

dbutils.fs.put("/foobar/baz.txt", "Hello, World!")

dbutils.fs.head("/foobar/baz.txt")

dbutils.fs.rm("/foobar/baz.txt")

display(dbutils.fs.ls("dbfs:/foobar"))
#Acceso disco local
dbutils.fs.ls("file:/foobar")

# %%
# Recursively remove the files under foobar

# %fs rm -r foobar

# Overwrite the file "/mnt/my-file" with the string "Hello world!"

# %fs put -f "/mnt/my-file" "Hello world!"

# %%
# %sql
DROP TABLE IF EXISTS radio_sample_data;
CREATE TABLE radio_sample_data
USING json
OPTIONS (
 path "/mnt/curso/JSON/small_radio_json.json"
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
SELECT * from radio_sample_data
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
