# %%
text_RDD = sc.texfile("/example/data/gutenberg/davinci.txt")
text_RDD.take(1)

def split_words(line):
    return line.split()

def create_pair(word):
    return(word,1)

pairs_RDD=text_RDD.flatMap(split_words).map(create_pair)
pairs_RDD.collect()

def sum_counts(a,b):
    return a+b

wordcounts_RDD=pairs_RDD.reduceByKey(sum__counts)

wordcounts_RDD.collect()

# %%
def lowerIline:
    return line.lower()
lower_text_RDD = text_RDD.map(lower)

def split_words(line):
    return line.split()
words_RDD = text_RDD.flatMap(split_words)
words_RDD.collect()

def starts_with_a(word):
    return word.lower().startswith("a")
words_RDD.filter(starts_with_a).collect()

someRDD.setName("toy").cache

sc.parallelize(Rango(10),4).coalesce(2).glom().collect()

pairs_RDD.grupByKey().collect()

for k,v in pairs_RDD.groupByKey().collect():
    print "Key:",k ",Values:" , list(v)

# %%
 ints = sc.parallelize(1 to 100, 4)


ints.partitions.size
# Out:
# Starting Spark application
# <table>
# <tr><th>ID</th><th>YARN Application ID</th><th>Kind</th><th>State</th><th>Spark UI</th><th>Driver log</th><th>Current session?</th></tr><tr><td>7</td><td>application_1540562674778_0015</td><td>pyspark3</td><td>idle</td><td><a target="_blank" href="http://hn0-bdvita.yx4fzmlby1tebmbaxccjmz1fbd.ax.internal.cloudapp.net:8088/proxy/application_1540562674778_0015/">Link</a></td><td><a target="_blank" href="http://wn2-bdvita.yx4fzmlby1tebmbaxccjmz1fbd.ax.internal.cloudapp.net:30060/node/containerlogs/container_e04_1540562674778_0015_01_000001/livy">Link</a></td><td>✔</td></tr></table>
# SparkSession available as 'spark'.
# unexpected indent (<stdin>, line 2)
#   File "<stdin>", line 2
#     ints = sc.parallelize(1 to 100, 4)
#     ^
# IndentationError: unexpected indent
